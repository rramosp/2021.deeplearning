# %% [markdown]
# # LAB - Autoencoders

# %%
# !wget -nc --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/2021.deeplearning/main/content/init.py
import init; init.init(force_download=False);

# %%
import sys
if 'google.colab' in sys.modules:
    print ("setting tensorflow version in colab")
    # %tensorflow_version 2.x
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
mnist = pd.read_csv("local/data/mnist1.5k.csv.gz", compression="gzip", header=None).values
X=mnist[:,1:785]/255.
y=mnist[:,0]
print("dimension de las imagenes y las clases", X.shape, y.shape)
# Out:
# dimension de las imagenes y las clases (1500, 784) (1500,)

# %%
perm = np.random.permutation(list(range(X.shape[0])))[0:50]
random_imgs   = X[perm]
random_labels = y[perm] 
fig = plt.figure(figsize=(10,6))
for i in range(random_imgs.shape[0]):
    ax=fig.add_subplot(5,10,i+1)
    plt.imshow(random_imgs[i].reshape(28,28), interpolation="nearest", cmap = plt.cm.Greys_r)
    ax.set_title(int(random_labels[i]))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

# %% [markdown]
# ## Autoencoder with small (sparse) activations

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.backend import clear_session
from tensorflow.keras.regularizers import l1
import tensorflow as tf

# %% [markdown]
# ## Implement the following loss function
#
# given:
#
# - $k=50$, latent dimension
# - $\mathbf{x}^{(i)} \in \mathbb{R}^{784}$
# - $e(\mathbf{x}^{(i)}) \in \mathbb{R}^{k}$, the encoder
# - $d(e(\mathbf{x}^{(i)})) \in \mathbb{R}^{784}$, the decoder
#
# implement the following cost function
#
# $$\text{loss}(\mathbf{x}^{(i)}) = \frac{1}{m}\sum_m \big(\mathbf{x}^{(i)} - d(e(\mathbf{x}^{(i)}))\big)^2 + \beta \frac{1}{k}\sum_{k,i} e(\mathbf{x}^{(i)})$$

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.losses import mse


def get_model(input_dim, code_size, beta=.01):
    inputs = Input(shape=input_dim)
    encoder = Dense(code_size, activation='relu')(inputs)
    outputs = Dense(input_dim, activation='sigmoid')(encoder)

    avg_latent_activations = ...
    loss = ...

    model = Model([inputs], [outputs])    
    model.add_loss(loss)

    model.compile(optimizer='adam')
    return model, encoder, avg_latent_activations

# %%
model, encoder, avg_latent_activations = get_model(input_dim=X.shape[1], code_size=50, beta=0.05)
# Out:
# W0220 14:44:45.825977 4384662976 training_utils.py:1444] Output dense_27 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to dense_27.

# %% [markdown]
# try with larger layer, try with more layers

# %%
model.fit(X_train, epochs=100, batch_size=32)
# Out:
# Train on 1200 samples
# Epoch 1/100
# 1200/1200 [==============================] - 0s 171us/sample - loss: 0.2083
# Epoch 2/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.1205
# Epoch 3/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.1021
# Epoch 4/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0931
# Epoch 5/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0850
# Epoch 6/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0774
# Epoch 7/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0709
# Epoch 8/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0661
# Epoch 9/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0631
# Epoch 10/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0608
# Epoch 11/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0588
# Epoch 12/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0571
# Epoch 13/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0557
# Epoch 14/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0545
# Epoch 15/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0535
# Epoch 16/100
# 1200/1200 [==============================] - 0s 51us/sample - loss: 0.0526
# Epoch 17/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0517
# Epoch 18/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0510
# Epoch 19/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0503
# Epoch 20/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0497
# Epoch 21/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0492
# Epoch 22/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0487
# Epoch 23/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0482
# Epoch 24/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0477
# Epoch 25/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0473
# Epoch 26/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0469
# Epoch 27/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0465
# Epoch 28/100
# 1200/1200 [==============================] - 0s 43us/sample - loss: 0.0462
# Epoch 29/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0458
# Epoch 30/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0455
# Epoch 31/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0452
# Epoch 32/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0449
# Epoch 33/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0446
# Epoch 34/100
# 1200/1200 [==============================] - 0s 51us/sample - loss: 0.0444
# Epoch 35/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0441
# Epoch 36/100
# 1200/1200 [==============================] - 0s 43us/sample - loss: 0.0438
# Epoch 37/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0436
# Epoch 38/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0434
# Epoch 39/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0431
# Epoch 40/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0429
# Epoch 41/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0427
# Epoch 42/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0425
# Epoch 43/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0423
# Epoch 44/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0421
# Epoch 45/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0419
# Epoch 46/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0417
# Epoch 47/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0415
# Epoch 48/100
# 1200/1200 [==============================] - 0s 54us/sample - loss: 0.0413
# Epoch 49/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0411
# Epoch 50/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0409
# Epoch 51/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0408
# Epoch 52/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0406
# Epoch 53/100
# 1200/1200 [==============================] - 0s 57us/sample - loss: 0.0404
# Epoch 54/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0403
# Epoch 55/100
# 1200/1200 [==============================] - 0s 57us/sample - loss: 0.0401
# Epoch 56/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0399
# Epoch 57/100
# 1200/1200 [==============================] - 0s 56us/sample - loss: 0.0398
# Epoch 58/100
# 1200/1200 [==============================] - 0s 58us/sample - loss: 0.0396
# Epoch 59/100
# 1200/1200 [==============================] - 0s 60us/sample - loss: 0.0395
# Epoch 60/100
# 1200/1200 [==============================] - 0s 56us/sample - loss: 0.0393
# Epoch 61/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0392
# Epoch 62/100
# 1200/1200 [==============================] - 0s 43us/sample - loss: 0.0390
# Epoch 63/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0389
# Epoch 64/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0387
# Epoch 65/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0386
# Epoch 66/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0385
# Epoch 67/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0383
# Epoch 68/100
# 1200/1200 [==============================] - 0s 51us/sample - loss: 0.0382
# Epoch 69/100
# 1200/1200 [==============================] - 0s 56us/sample - loss: 0.0380
# Epoch 70/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0379
# Epoch 71/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0378
# Epoch 72/100
# 1200/1200 [==============================] - 0s 60us/sample - loss: 0.0377
# Epoch 73/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0375
# Epoch 74/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0374
# Epoch 75/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0373
# Epoch 76/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0372
# Epoch 77/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0370
# Epoch 78/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0369
# Epoch 79/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0368
# Epoch 80/100
# 1200/1200 [==============================] - 0s 42us/sample - loss: 0.0367
# Epoch 81/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0366
# Epoch 82/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0365
# Epoch 83/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0363
# Epoch 84/100
# 1200/1200 [==============================] - 0s 44us/sample - loss: 0.0362
# Epoch 85/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0361
# Epoch 86/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0360
# Epoch 87/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0359
# Epoch 88/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0358
# Epoch 89/100
# 1200/1200 [==============================] - 0s 44us/sample - loss: 0.0357
# Epoch 90/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0356
# Epoch 91/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0355
# Epoch 92/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0354
# Epoch 93/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0353
# Epoch 94/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0352
# Epoch 95/100
# 1200/1200 [==============================] - 0s 55us/sample - loss: 0.0351
# Epoch 96/100
# 1200/1200 [==============================] - 0s 53us/sample - loss: 0.0350
# Epoch 97/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0349
# Epoch 98/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0348
# Epoch 99/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0348
# Epoch 100/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0347

# %%
fl = K.function([model.input], [avg_latent_activations])
fl(X_train)
# Out:
# [array([4.4608349e-01, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 2.8072491e-01, 3.8508105e-01, 4.1526198e-01,
#         1.7899944e-03, 0.0000000e+00, 0.0000000e+00, 4.2354482e-01,
#         0.0000000e+00, 0.0000000e+00, 3.9055079e-01, 0.0000000e+00,
#         3.2591656e-01, 6.4026034e-01, 0.0000000e+00, 4.1022152e-01,
#         5.5418462e-01, 6.2894529e-01, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.8380924e-01,
#         0.0000000e+00, 0.0000000e+00, 3.5680971e-01, 0.0000000e+00,
#         0.0000000e+00, 5.9563463e-04, 0.0000000e+00, 4.6177214e-01,
#         0.0000000e+00, 5.4042482e-01, 0.0000000e+00, 0.0000000e+00,
#         5.9360516e-01, 0.0000000e+00, 4.7642380e-01, 0.0000000e+00,
#         5.6514001e-01, 0.0000000e+00, 3.5979575e-01, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00], dtype=float32)]

# %% [markdown]
# ###  test the reconstruction

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ### show the weights

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ### show activations in latent space
#
# you should get something similar to this, indicating a much more sparse representation

# %%
from IPython.display import Image
Image(filename='local/imgs/ae_sparse_activations.png')

# %%
...

# %% [markdown]
# ### show the distribution of activations in latent space
#
# should be quite concentrated at 0

# %%
...

# %% [markdown]
# ### show most representative neuron in latent space for each class
#
# now, representative neurons must show somewhat distinctive shapes for each number

# %%
...
